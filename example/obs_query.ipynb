# %%
# %load_ext autoreload

# %autoreload 2


import datetime
from verif.data.obs import ddb

# %%
obs_id = "NZCQX_nzaws"
dt_start = datetime.datetime(2023, 3, 1)
dt_end = datetime.datetime(2023, 3, 30)

# %%
obs_all = ddb.get_obs_all(obs_id, dt_start, dt_end, table_recent=True)
obs_gust = ddb.extract_obs_data(obs_all, "windGustMaximum@1h", "hourly")
obs_gust.plot()

# %%
obs_gust
# Out:
# <xarray.DataArray (time: 548)>
# array([12.347, 14.404, 13.376, 14.919, 14.404, 14.919, 14.404, 13.376,
#        12.861, 10.289,  8.231,  8.231,  6.688,  6.173,  3.601,  4.63 ,
#         2.572,  3.087,  3.601,  3.601,  3.601,  3.601,  4.63 ,  6.688,
#         7.717,  8.231,  9.774,  9.26 ,  9.774,  9.774,  9.26 ,  7.202,
#         3.601,  2.572,  3.601,  5.144,  4.116,  3.087,  3.601,  3.601,
#         3.087,  2.058,  3.087,  3.601,  3.601,  6.173,  7.202,  8.231,
#         9.774,  9.774,  7.717,  5.659,  4.116,  4.116,  2.572,  2.572,
#         8.746,  9.774, 10.289, 10.803,  9.774,  8.746, 10.289,  8.746,
#         8.746,  8.231,  6.688,  7.717,  7.717,  5.659,  7.202,  6.688,
#         7.202,  8.746,  6.688,  7.717,  5.144,  6.688,  3.087,  3.601,
#         4.116,  5.659,  7.202,  6.173,  4.63 ,  5.144,  6.688,  3.601,
#         4.63 ,  4.116,  4.63 ,  5.659,  6.173,  6.173,  8.746,  8.231,
#         5.144,  7.717,  7.202,  5.659,  4.63 ,  5.144,  4.63 ,  4.63 ,
#         4.116,  4.63 ,  4.116,  4.63 ,  5.144,  3.087,  4.116,  6.173,
#         6.173,  5.659,  5.144,  4.63 ,  4.116,  4.116,  9.26 ,  9.26 ,
#         9.26 ,  9.774, 10.289,  9.774, 11.318, 10.289,  8.746,  8.231,
#         7.202,  7.717,  6.688,  5.659,  4.63 ,  4.116,  5.659,  5.659,
#         8.231,  9.774, 10.289, 10.803, 10.803, 10.289, 11.318, 10.803,
#        13.89 , 13.376, 11.832, 11.318, 13.376, 11.832, 10.803,  9.774,
#         9.26 , 10.289,  9.26 ,  9.26 ,  8.746,  7.717,  7.717,  6.173,
# ...
#        13.376, 11.318,  9.774, 10.289,  9.26 ,  8.231,  6.173,  6.688,
#         4.63 ,  2.572,  2.058,  5.144,  6.173,  6.173,  7.202,  9.26 ,
#        10.289, 11.318, 11.832, 13.89 , 13.376, 11.832, 12.861, 11.318,
#        12.347, 12.347, 11.832, 10.803,  8.746,  6.688,  3.601,  2.572,
#         3.087,  2.572,  2.572, 14.919, 15.948, 13.89 , 18.52 , 19.034,
#         9.774, 11.832, 16.462, 15.948, 14.919, 15.948, 14.404, 12.861,
#        13.89 ,  8.231, 14.404, 22.636, 26.237, 28.294, 15.948, 21.092,
#        18.006, 21.607, 21.092, 24.179, 22.121, 22.121, 24.693, 22.121,
#        27.266, 23.664, 22.121, 20.578, 21.092, 19.034, 22.636, 19.034,
#        15.433, 18.006, 16.462, 18.52 , 16.977, 21.092, 17.491, 14.919,
#        16.462, 16.462, 15.948, 12.861, 16.977, 15.433, 11.318, 13.89 ,
#        13.89 , 15.433, 10.289,  8.231,  6.688,  5.659,  3.601,  2.572,
#         2.572,  9.774, 16.462, 10.803,  7.202, 11.318, 16.977, 16.462,
#        15.433, 18.52 , 20.578, 21.607, 15.948, 18.52 , 21.092, 17.491,
#        13.89 , 17.491, 18.52 , 15.948, 18.006, 19.034, 15.433, 21.092,
#        11.318, 21.092, 15.433, 18.006, 16.462, 20.063, 17.491, 12.347,
#        18.52 , 16.977, 18.52 , 19.034, 19.549, 16.462, 16.977, 16.462,
#        17.491, 14.404, 14.919, 13.376, 11.318, 12.861, 12.347, 12.347,
#        10.289, 13.89 , 13.89 , 13.376, 12.861, 14.919, 14.404, 15.948,
#        14.404, 13.376, 13.89 , 15.433])
# Coordinates:
#   * time     (time) datetime64[ns] 2023-03-01 2023-03-01T01:00:00 ... 2023-03-30

# %%
obs_all = ddb.get_obs_all(obs_id, dt_start, dt_end, table_recent=False)
obs_gust = ddb.extract_obs_data(obs_all, "windGustMaximum@1h", "hourly")
obs_gust.plot()

# %% [markdown]
# # DynamoDB Experiments

# %%
import boto3

# create a DynamoDB client
dynamodb = boto3.client('dynamodb')

# specify the table name and attribute name you want to query
table_name = 'prod_observations_archive_2022'
attribute_name = 'obs_id'

# create a query expression to get unique values for the attribute
query_params = {
    'TableName': table_name,
    'ProjectionExpression': attribute_name,
    'Select': 'SPECIFIC_ATTRIBUTES'
}

# execute the query and get the results
response = dynamodb.query(**query_params)

# extract the unique values from the response
unique_values = set([item[attribute_name] for item in response['Items']])
# Out:
# ---------------------------------------------------------------------------
#
# ClientError                               Traceback (most recent call last)
#
# Cell In[58], line 18
#
#      11 query_params = {
#
#      12     'TableName': table_name,
#
#      13     'ProjectionExpression': attribute_name,
#
#      14     'Select': 'SPECIFIC_ATTRIBUTES'
#
#      15 }
#
#      17 # execute the query and get the results
#
# ---> 18 response = dynamodb.query(**query_params)
#
#      20 # extract the unique values from the response
#
#      21 unique_values = set([item[attribute_name] for item in response['Items']])
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#
#     526     raise TypeError(
#
#     527         f"{py_operation_name}() only accepts keyword arguments."
#
#     528     )
#
#     529 # The "self" in this scope is referring to the BaseClient.
#
# --> 530 return self._make_api_call(operation_name, kwargs)
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#
#     959     error_class = self.exceptions.from_code(error_code)
#
# --> 960     raise error_class(parsed_response, operation_name)
#
#     961 else:
#
#     962     return parsed_response
#
#
#
# ClientError: An error occurred (ValidationException) when calling the Query operation: Either the KeyConditions or KeyConditionExpression parameter must be specified in the request.

# %%
import boto3

# create a DynamoDB client
dynamodb = boto3.client('dynamodb')

# specify the table name and attribute name you want to query
table_name = 'prod_observations_archive_2022'
attribute_name = 'obs_id'

# create a PartiQL query to get distinct values for the attribute
query_params = {
    'Statement': """SELECT obs_id, "code-wmo", valid_time, airTemperature
                    FROM "prod_observations_archive_2022"
                    -- WHERE begins_with(valid_time, '202201010')
                    WHERE valid_time BETWEEN '20220101000000' AND '20220201000000'"""
}

# execute the query and get the results
response = dynamodb.execute_statement(**query_params)

# extract the unique values from the response
# unique_values = set([item[attribute_name]['S'] for item in response['Items']])

# %%
import boto3

dynamodb = boto3.client('dynamodb')

# Define the PartiQL statement
statement = """SELECT obs_id, "code-wmo", valid_time, airTemperature
                    FROM "prod_observations_archive_2022"
                    WHERE begins_with(valid_time, '202201010')
                    AND "code-wmo"=='93439'
                    ---WHERE valid_time BETWEEN '20220101000000' AND '20220201000000'"""

# Set the consistent read option to true
params = {
    'Statement': statement,
    'ConsistentRead': True
}

# Keep track of the items retrieved
items = []

# Loop through the pages of results
while True:
    # Execute the PartiQL statement with optional NextToken parameter
    response = dynamodb.execute_statement(**query_params)

    # Add the items from the current page to the list of items
    items.extend(response['Items'])

    # Check if there are more pages of results
    if 'NextToken' in response:
        # Set the NextToken parameter to retrieve the next page of results
        params['NextToken'] = response['NextToken']
    else:
        # No more pages of results, break out of the loop
        break
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[112], line 24
#
#      21 # Loop through the pages of results
#
#      22 while True:
#
#      23     # Execute the PartiQL statement with optional NextToken parameter
#
# ---> 24     response = dynamodb.execute_statement(**query_params)
#
#      26     # Add the items from the current page to the list of items
#
#      27     items.extend(response['Items'])
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#
#     526     raise TypeError(
#
#     527         f"{py_operation_name}() only accepts keyword arguments."
#
#     528     )
#
#     529 # The "self" in this scope is referring to the BaseClient.
#
# --> 530 return self._make_api_call(operation_name, kwargs)
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/client.py:943, in BaseClient._make_api_call(self, operation_name, api_params)
#
#     941 else:
#
#     942     apply_request_checksum(request_dict)
#
# --> 943     http, parsed_response = self._make_request(
#
#     944         operation_model, request_dict, request_context
#
#     945     )
#
#     947 self.meta.events.emit(
#
#     948     'after-call.{service_id}.{operation_name}'.format(
#
#     949         service_id=service_id, operation_name=operation_name
#
#    (...)
#
#     954     context=request_context,
#
#     955 )
#
#     957 if http.status_code >= 300:
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/client.py:966, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#
#     964 def _make_request(self, operation_model, request_dict, request_context):
#
#     965     try:
#
# --> 966         return self._endpoint.make_request(operation_model, request_dict)
#
#     967     except Exception as e:
#
#     968         self.meta.events.emit(
#
#     969             'after-call-error.{service_id}.{operation_name}'.format(
#
#     970                 service_id=self._service_model.service_id.hyphenize(),
#
#    (...)
#
#     974             context=request_context,
#
#     975         )
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#
#     113 def make_request(self, operation_model, request_dict):
#
#     114     logger.debug(
#
#     115         "Making request for %s with params: %s",
#
#     116         operation_model,
#
#     117         request_dict,
#
#     118     )
#
# --> 119     return self._send_request(request_dict, operation_model)
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/endpoint.py:202, in Endpoint._send_request(self, request_dict, operation_model)
#
#     198 request = self.create_request(request_dict, operation_model)
#
#     199 success_response, exception = self._get_response(
#
#     200     request, operation_model, context
#
#     201 )
#
# --> 202 while self._needs_retry(
#
#     203     attempts,
#
#     204     operation_model,
#
#     205     request_dict,
#
#     206     success_response,
#
#     207     exception,
#
#     208 ):
#
#     209     attempts += 1
#
#     210     self._update_retries_context(context, attempts, success_response)
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/botocore/endpoint.py:373, in Endpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#
#     366 else:
#
#     367     # Request needs to be retried, and we need to sleep
#
#     368     # for the specified number of times.
#
#     369     logger.debug(
#
#     370         "Response received to retry, sleeping for %s seconds",
#
#     371         handler_response,
#
#     372     )
#
# --> 373     time.sleep(handler_response)
#
#     374     return True
#
#
#
# KeyboardInterrupt:

# %%
items
# Out:
# [{'airTemperature': {'N': '219.70000000000002'},
#   'valid_time': {'S': '20220113095012'},
#   'obs_id': {'S': '3ESIDRZA_amdar'}},
#  {'airTemperature': {'N': '219.20000000000002'},
#   'valid_time': {'S': '20
'},
#   'obs_id': {'S': '94300_23_pilot'}},
#  {'code-wmo': {'S': '94300'},
#   'valid_time': {'S': '20220113043000'},
#   'obs_id': {'S': '94300_23_pilot'}},
#  ...]

# %%
obs_id = 'NZCQX_nzaws'
dt_start = pd.to_datetime(ds0['validtime'].min().values)
dt_end = pd.to_datetime(ds0['validtime'].max().values)

dt1 = datetime.datetime(2022,1, 1)
dt2 = datetime.datetime(2022,1, 2)

# %%
obs_all = ddb.get_obs_all(obs_id, dt1, dt2, table_recent=True)
obs_temp = ddb.extract_obs_data(obs_all, "windGustMaximum@1h", "hourly")
obs_temp.plot()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[58], line 3
#
#       1 obs_all = ddb.get_obs_all(obs_id, dt1, dt2, table_recent=True)
#
#       2 obs_temp = ddb.extract_obs_data(obs_all, "windGustMaximum@1h", "hourly")
#
# ----> 3 obs_temp.plot()
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/xarray/plot/accessor.py:47, in DataArrayPlotAccessor.__call__(self, **kwargs)
#
#      45 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#
#      46 def __call__(self, **kwargs) -> Any:
#
# ---> 47     return dataarray_plot.plot(self._da, **kwargs)
#
#
#
# File ~/miniconda3/envs/verif/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:279, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#
#     276 plotfunc: Callable
#
#     278 if ndims == 0 or darray.size == 0:
#
# --> 279     raise TypeError("No numeric data to plot.")
#
#     280 if ndims in (1, 2):
#
#     281     if row or col:
#
#
#
# TypeError: No numeric data to plot.

# %%
obs_all
# Out:
# []

# %%
session = boto3.Session()
resource_ddb = session.resource("dynamodb", region_name="us-west-2")
from boto3.dynamodb.conditions import Key

dt1 = datetime.datetime(2022,1, 1).strftime(dt_start, "%Y%m%d%H%M%S")
dt2 = datetime.datetime(2022,1, 2).strftime(dt_end, "%Y%m%d%H%M%S")

ddb_table = resource_ddb.Table('prod_observations_archive_2022')
response = ddb_table.query(
    KeyConditionExpression=Key("obs_id").eq('NZCQX_nzaws')
    & Key("valid_time").between(dt_1, dt_2)
)
result.extend(response["Items"])
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[60], line 5
#
#       2 resource_ddb = session.resource("dynamodb", region_name="us-west-2")
#
#       3 from boto3.dynamodb.conditions import Key
#
# ----> 5 dt1 = datetime.datetime(2022,1, 1).strftime(dt_start, "%Y%m%d%H%M%S")
#
#       6 dt2 = datetime.datetime(2022,1, 2).strftime(dt_end, "%Y%m%d%H%M%S")
#
#       8 ddb_table = resource_ddb.Table('prod_observations_archive_2022')
#
#
#
# TypeError: strftime() takes at most 1 argument (2 given)

# %%
datetime.datetime.strftime(dt_end, "%Y%m%d%H%M%S")
# Out:
# '20220116000000'

# %%
response
# Out:
# {'Items': [],
#  'NextToken': '...',
#  'LastEvaluatedKey': {'obs_id': {'S': '94300_23_pilot'},
#   'valid_time': {'S': '20220123060000'}},
#  'ResponseMetadata': {'RequestId': '3P5MKQP44AUOK5RNVHETJQKUQBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 04 Apr 2023 03:55:49 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '516',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '3P5MKQP44AUOK5RNVHETJQKUQBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '3658828827'},
#   'RetryAttempts': 0}}
