# %% [markdown]
# # 1 minute Obs API

# %%
# %load_ext autoreload
# %autoreload 2

import requests
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
api_key = 'l7cbe81bcebc534e2a98815fc5b1962ce5'

# %%
headers = {'apikey': api_key}
newSession = requests.Session()
response = newSession.get('https://test-api.metservice.com/observations/nz/1-minute/weatherStation/90292/last/1440/minutes?format=json',
                           headers=headers) 
response.json()
# Out:
# {'version': '1.0',
#  'request-time': '2023-04-10T22:05:11Z',
#  'path': '/observations/nz/1-minute/weatherStation/90292/last/1440/minutes?format=json',
#  'attributes': {'dataset': 'observation:1minuteobservation',
#   'provider': 'metservice',
#   'station': '90292',
#   'station-alpha': 'NZJDX'},
#  'results': [{'obs_timestamp': '2023-04-10T22:03:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 313,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 85.4,
#    'dewtemp_01mnavg': 15.0,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 334,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 77.6,
#    'wnddirm_01mnavg': 304,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 77.7,
#    'winddir_01mnavg': 325,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 13.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T22:02:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 313,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 85.4,
#    'dewtemp_01mnavg': 15.1,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 334,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 77.6,
#    'wnddirm_01mnavg': 311,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.2,
#    'winddir_01mnavg': 332,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 19.0,
#    'windrun_01hracc': 13.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T22:01:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 312,
#    'pressen_01hrchg': 0.0,
#    'relhumd_01hrmax': 85.4,
#    'dewtemp_01mnavg': 14.9,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 333,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 77.6,
#    'wnddirm_01mnavg': 318,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 77.6,
#    'winddir_01mnavg': 339,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 13.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T22:00:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 311,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.0,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 332,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.5,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.5,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 19.0,
#    'windrun_01hracc': 13.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:59:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 311,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.0,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 332,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 317,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.8,
#    'winddir_01mnavg': 338,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 19.0,
#    'windrun_01hracc': 13.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:58:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 309,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.0,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 330,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 302,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 79.1,
#    'winddir_01mnavg': 323,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 19.0,
#    'windrun_01hracc': 13.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:57:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 310,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 331,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 317,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 79.1,
#    'winddir_01mnavg': 338,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 19.0,
#    'windrun_01hracc': 13.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:56:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 307,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 328,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 311,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.7,
#    'winddir_01mnavg': 332,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 318,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 13.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.7,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 339,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:55:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 307,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 328,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 315,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 79.0,
#    'winddir_01mnavg': 336,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 319,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 12.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 340,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:54:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 332,
#    'wnddirm_10mnavg': 308,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.1,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 329,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 309,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.6,
#    'winddir_01mnavg': 330,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 319,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 12.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 340,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 353,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:53:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 309,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.1,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 330,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 304,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.7,
#    'winddir_01mnavg': 325,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 319,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 12.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.5,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 340,
#    'pressen_01hrmin': 995.7,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:52:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 311,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.1,
#    'dewtemp_01mnavg': 15.0,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 332,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 299,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.6,
#    'winddir_01mnavg': 320,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 319,
#    'airtemp_01mnavg': 18.8,
#    'windrun_01hracc': 12.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.5,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 340,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:51:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 314,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.2,
#    'dewtemp_01mnavg': 15.0,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 335,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 78.6,
#    'wnddirm_01mnavg': 314,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 78.6,
#    'winddir_01mnavg': 335,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 320,
#    'airtemp_01mnavg': 18.8,
#    'windrun_01hracc': 12.8,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 341,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:50:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 315,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 336,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 79.9,
#    'wnddirm_01mnavg': 319,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 79.9,
#    'winddir_01mnavg': 340,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 320,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 12.7,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.3,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 341,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:49:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 316,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 337,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 79.9,
#    'wnddirm_01mnavg': 299,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.1,
#    'winddir_01mnavg': 320,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 319,
#    'airtemp_01mnavg': 18.9,
#    'windrun_01hracc': 12.7,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.2,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 340,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.9,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:48:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 317,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 338,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 79.9,
#    'wnddirm_01mnavg': 311,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 79.9,
#    'winddir_01mnavg': 332,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 320,
#    'airtemp_01mnavg': 18.8,
#    'windrun_01hracc': 12.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.2,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 341,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.8,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:47:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 318,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 339,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.1,
#    'wnddirm_01mnavg': 292,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.1,
#    'winddir_01mnavg': 313,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 313,
#    'wnddirm_01hravg': 320,
#    'airtemp_01mnavg': 18.8,
#    'windrun_01hracc': 12.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.1,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 341,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.8,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 292,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:46:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 9,
#    'relhumd_01hrmin': 80.1,
#    'wnddirm_01mnavg': 310,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.1,
#    'winddir_01mnavg': 331,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 320,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 341,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:45:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 9,
#    'relhumd_01hrmin': 80.2,
#    'wnddirm_01mnavg': 319,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.2,
#    'winddir_01mnavg': 340,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.9,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:44:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 333,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.2,
#    'wnddirm_01mnavg': 324,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.5,
#    'winddir_01mnavg': 345,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.9,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 354,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.7,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:43:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 9,
#    'relhumd_01hrmin': 80.2,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.4,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.1,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:42:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.4,
#    'dewtemp_01mnavg': 15.2,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.2,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.2,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:41:00Z',
#    'windspd_01hravg': 7,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.5,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.8,
#    'wnddirm_01mnavg': 326,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 81.0,
#    'winddir_01mnavg': 347,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 12.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.7,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:40:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.8,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.8,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.9,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 11.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.7,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:39:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.8,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.8,
#    'wnddirm_01mnavg': 317,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 81.0,
#    'winddir_01mnavg': 338,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.7,
#    'windrun_01hracc': 11.8,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.7,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.7,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:38:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 86.9,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.8,
#    'wnddirm_01mnavg': 317,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.8,
#    'winddir_01mnavg': 338,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.8,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.6,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:37:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.0,
#    'dewtemp_01mnavg': 15.3,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 80.9,
#    'wnddirm_01mnavg': 326,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 80.9,
#    'winddir_01mnavg': 347,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:36:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 324,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 87.2,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 345,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 81.2,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 81.2,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:35:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 324,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.3,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 345,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 81.4,
#    'wnddirm_01mnavg': 322,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 81.4,
#    'winddir_01mnavg': 343,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:34:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.4,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 81.5,
#    'wnddirm_01mnavg': 324,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 81.5,
#    'winddir_01mnavg': 345,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:33:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.6,
#    'dewtemp_01mnavg': 15.5,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.0,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 82.0,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 11.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:32:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.8,
#    'dewtemp_01mnavg': 15.5,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.1,
#    'wnddirm_01mnavg': 313,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 82.1,
#    'winddir_01mnavg': 334,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 11.1,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:31:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 323,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 87.9,
#    'dewtemp_01mnavg': 15.4,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 344,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 332,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 82.2,
#    'winddir_01mnavg': 353,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 11.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:30:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 88.1,
#    'dewtemp_01mnavg': 15.5,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 82.8,
#    'wnddirm_01mnavg': 329,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 82.8,
#    'winddir_01mnavg': 350,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.8,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:29:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 88.3,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 83.2,
#    'wnddirm_01mnavg': 315,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 83.3,
#    'winddir_01mnavg': 336,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.7,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:28:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 88.5,
#    'dewtemp_01mnavg': 15.6,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 83.2,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 83.2,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.5,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:27:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 88.8,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 83.6,
#    'wnddirm_01mnavg': 330,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 83.6,
#    'winddir_01mnavg': 351,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:26:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 322,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 88.9,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 343,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.1,
#    'wnddirm_01mnavg': 324,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.1,
#    'winddir_01mnavg': 345,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.6,
#    'windrun_01hracc': 10.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.6,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:25:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.0,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.2,
#    'wnddirm_01mnavg': 316,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.2,
#    'winddir_01mnavg': 337,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 321,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 342,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.5,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.1,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:24:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 319,
#    'pressen_01hrchg': 0.5,
#    'relhumd_01hrmax': 89.1,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 340,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 312,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.4,
#    'winddir_01mnavg': 333,
#    'windspd_01mnavg': 4,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.5,
#    'windrun_01hracc': 10.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.5,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:23:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.2,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 320,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.5,
#    'winddir_01mnavg': 341,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 10.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:22:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.5,
#    'relhumd_01hrmax': 89.2,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 327,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.3,
#    'winddir_01mnavg': 348,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 10.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.6,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:21:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.5,
#    'relhumd_01hrmax': 89.4,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 6,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 321,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.5,
#    'winddir_01mnavg': 342,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 10.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.5,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:20:00Z',
#    'windspd_01hravg': 6,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.5,
#    'relhumd_01hrmax': 89.5,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 316,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.5,
#    'winddir_01mnavg': 337,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 10.1,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.5,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.9,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:19:00Z',
#    'windspd_01hravg': 5,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.6,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.4,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.3,
#    'windrun_01hracc': 10.0,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:18:00Z',
#    'windspd_01hravg': 5,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 321,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.6,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 342,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 331,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.7,
#    'winddir_01mnavg': 352,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 9.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.4,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:17:00Z',
#    'windspd_01hravg': 5,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.7,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 341,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 84.3,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 84.7,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 318,
#    'wnddirm_01hravg': 322,
#    'airtemp_01mnavg': 18.3,
#    'windrun_01hracc': 9.9,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 16.3,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 343,
#    'pressen_01hrmin': 995.4,
#    'airtemp_01hrmax': 18.3,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 358,
#    'wndccwm_01hrmax': 297,
#    'pressen_01mnavg': 995.8,
#    'power_v_01mnavg': 14.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T21:16:00Z',
#    'windspd_01hravg': 5,
#    'wndcwm__01hrmax': 337,
#    'wnddirm_10mnavg': 320,
#    'pressen_01hrchg': 0.4,
#    'relhumd_01hrmax': 89.8,
#    'dewtemp_01mnavg': 15.6,
#    'pressen_01hrmax': 995.9,
#    'fixlone_01mnavg': 'E',
# ...
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.5,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 349,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 329,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.1,
#    'winddir_01mnavg': 350,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 17.8,
#    'windrun_01hracc': 14.1,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.8,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:36:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 329,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.5,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 350,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.1,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 17.9,
#    'windrun_01hracc': 14.2,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.9,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:35:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 329,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.6,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 350,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.2,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 17.9,
#    'windrun_01hracc': 14.3,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 17.9,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:34:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.6,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 326,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.2,
#    'winddir_01mnavg': 347,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.0,
#    'windrun_01hracc': 14.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.4,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:33:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.2,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.0,
#    'windrun_01hracc': 14.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.0,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:32:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.7,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 331,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.2,
#    'winddir_01mnavg': 352,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 328,
#    'airtemp_01mnavg': 18.1,
#    'windrun_01hracc': 14.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.1,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 349,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.0,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:31:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 323,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 344,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.1,
#    'windrun_01hracc': 14.4,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.1,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:30:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.8,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 327,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 348,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 328,
#    'airtemp_01mnavg': 18.1,
#    'windrun_01hracc': 14.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.1,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 349,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:29:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 330,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.9,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 351,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 340,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 1,
#    'windspd_01mnavg': 8,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.2,
#    'windrun_01hracc': 14.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.2,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:28:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 329,
#    'pressen_01hrchg': 0.1,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 15.9,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 350,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 336,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 357,
#    'windspd_01mnavg': 10,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.2,
#    'windrun_01hracc': 14.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.2,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:27:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 329,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.4,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 350,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 336,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 357,
#    'windspd_01mnavg': 5,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.3,
#    'windrun_01hracc': 14.5,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.3,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.4,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:26:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 328,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.3,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.3,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 349,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 8,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 325,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.3,
#    'winddir_01mnavg': 346,
#    'windspd_01mnavg': 9,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.3,
#    'windrun_01hracc': 14.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.3,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:25:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 327,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.2,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.3,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 348,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 332,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.2,
#    'winddir_01mnavg': 353,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.3,
#    'windrun_01hracc': 14.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.3,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.2,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:24:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 326,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 86.0,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.3,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 347,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 326,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 86.0,
#    'winddir_01mnavg': 347,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 14.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.3,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:23:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 326,
#    'pressen_01hrchg': 0.2,
#    'relhumd_01hrmax': 85.8,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.3,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 347,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 326,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 85.8,
#    'winddir_01mnavg': 347,
#    'windspd_01mnavg': 7,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 327,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 14.6,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 348,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.3,
#    'fixlond_01mnavg': 174},
#   {'obs_timestamp': '2023-04-10T05:22:00Z',
#    'windspd_01hravg': 8,
#    'wndcwm__01hrmax': 346,
#    'wnddirm_10mnavg': 325,
#    'pressen_01hrchg': 0.3,
#    'relhumd_01hrmax': 85.6,
#    'dewtemp_01mnavg': 16.0,
#    'pressen_01hrmax': 990.3,
#    'fixlone_01mnavg': 'E',
#    'winddir_10mnavg': 346,
#    'fixlatr_01mnavg': -39.1175,
#    'windspd_10mnavg': 7,
#    'relhumd_01hrmin': 82.2,
#    'wnddirm_01mnavg': 332,
#    'fixlatn_01mnavg': 'S',
#    'relhumd_01mnavg': 85.6,
#    'winddir_01mnavg': 353,
#    'windspd_01mnavg': 6,
#    'fixlatd_01mnavg': 39,
#    'windccw_01hrmax': 333,
#    'wnddirm_01hravg': 328,
#    'airtemp_01mnavg': 18.4,
#    'windrun_01hracc': 14.7,
#    'fixlatm_01mnavg': 7.05,
#    'airtemp_01hrmin': 18.4,
#    'fixlonm_01mnavg': 6.27,
#    'winddir_01hravg': 349,
#    'pressen_01hrmin': 990.0,
#    'airtemp_01hrmax': 19.1,
#    'fixlonr_01mnavg': 174.1045,
#    'fixhght_01mnavg': 93,
#    'windcw__01hrmax': 7,
#    'wndccwm_01hrmax': 312,
#    'pressen_01mnavg': 990.3,
#    'power_v_01mnavg': 13.3,
#    'fixlond_01mnavg': 174},
#   ...]}
