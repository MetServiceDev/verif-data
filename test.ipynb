# %%
# %load_ext autoreload

# %autoreload 2


import datetime
from os import environ
from verif.data import obs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
environ["AWS_PROFILE"]
# Out:
# 'research-normaluser'

# %%
obs_id = "NZCQX_nzaws"
dt_start = datetime.datetime(2023, 3, 1)
dt_end = datetime.datetime(2023, 3, 30)

obs_all = obs.ddb.get_obs_all(obs_id, dt_start, dt_end)
obs_gust = obs.ddb.extract_obs_data(obs_all, "windGustMaximum@1h", "hourly")

# %%
obs_gust.plot()
